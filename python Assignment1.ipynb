# %%
string1 = "Hello "
name= ("Rafida")
string2 = string1 + name
print(string2)
string3 = " , welcome to python programming"
string2 = string2 + string3
print(string2)
# Out:
# Hello Rafida
# Hello Rafida , welcome to python programming

# %%
string = "Hello Rafida, welcome to python programming"
# a. First character
print("First character:", string[0])
# b. Last character
print("Last character:", string[-1])
# c. First 5 character
print("First 5 character:",string[:5])
# d. Last 11 character
print("Last 11 character:",string[-11:])
# e. Reverse the string
print("Reverse:",string[::-1])
# f. Print the word python
print("python:",string[25:31])
# Out:
# First character: H
# Last character: g
# First 5 character: Hello
# Last 11 character: programming
# Reverse: gnimmargorp nohtyp ot emoclew ,adifaR olleH
# python: python

# %%
strM = "Python beginner tutorial"
# a. convert the sentence to uppercase
print("Uppercase:",strM.upper())
# b. convert the sentence to lowercase
print("Lowercase:",strM.lower())
# c. use capitalize and return the sentence
print("Capitalize:",strM.capitalize())
# d. count the total number of occurrences of character 't'
print("Count of 't':",strM.count('t'))
# e. Replace "python" with "Machine Learning"
print("Replaced:",strM.replace("Python", "Machine Learning"))
# Out:
# Uppercase: PYTHON BEGINNER TUTORIAL
# Lowercase: python beginner tutorial
# Capitalize: Python beginner tutorial
# Count of 't': 3
# Replaced: Machine Learning beginner tutorial

# %%
# Create two tuples
t1 = (10,20,30)
t2 = (40,50,60)
# a. Concatenate the two tuples
t_combine = t1 + t2
print("combined tuple:",t_combine)
# b. Repeat the elements of t_combine 3 times
print("Repeated tuple:",t_combine * 3)
# c. Access the 3rd element
print("3rd element:",t_combine[2])
# d. Access the first three elements
print("First three elements:",t_combine[:3])
# e. Access the last three elements
print("Last three elements:",t_combine[-3:])
# Out:
# combined tuple: (10, 20, 30, 40, 50, 60)
# Repeated tuple: (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# 3rd element: 30
# First three elements: (10, 20, 30)
# Last three elements: (40, 50, 60)
